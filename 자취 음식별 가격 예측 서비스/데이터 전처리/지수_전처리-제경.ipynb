# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
# def split_and_set(seq):
#   test_arr_2 = []
#   for s in seq:
#     ss = str(s).split("(")
#     if ss[0] != "nan":
#       test_arr_2.append(ss[0])
#     test_arr_2 = list(set(test_arr_2))
#   return(test_arr_2)

# %%
# result_2022 = split_and_set(df_2022["품목 이름"].unique()	)
# result_2022.sort()
# print(len(result_2022), result_2022)
# Out:
# 20 ['고등어', '냉동참조기', '달걀', '닭고기', '동태', '돼지고기', '명태', '무', '배', '배추', '사과', '상추', '쇠고기', '쌀', '애호박', '양파', '오이', '오징어', '조기', '호박']

# %%
# df_only_apple = df_2022[df_2022['품목 이름'] == '사과']
# df_only_apple
# df_only_apple["년도-월"].unique
# Out:
# <bound method Series.unique of 200      2022-01
# 336      2022-01
# 352      2022-01
# 368      2022-01
# 384      2022-01
#           ...
# 79960    2022-12
# 80113    2022-12
# 80129    2022-12
# 80145    2022-12
# 80161    2022-12
# Name: 년도-월, Length: 1115, dtype: object>

# %%
# df_추리기 = df_2022[df_2022['품목 이름'].isin(['고등어', '냉동참조기', '달걀', '닭고기', '동태', '돼지고기', '명태', '무', '배', '배추', '사과', '상추', '쇠고기', '쌀', '애호박', '양파', '오이', '오징어', '조기', '호박'])]
# df_추리기
# Out:
#        Unnamed: 0     일련번호  시장/마트 번호      시장/마트 이름  품목 번호 품목 이름     실판매규격  \
# 4               4  1721875        55          광장시장     24    양파  1망 1.5kg
# 23             23  1721894         1          통인시장     22    오이        1개
# 36             36  1721907        56         롯데백화점     26    배추       1포기
# 41             41  1721912        56         롯데백화점    312   애호박        1개
# 48             48  1721919        56         롯데백화점    302    명태       1마리
# ...           ...      ...       ...           ...    ...   ...       ...
# 80269       80269  1804505         6       이마트 용산점    312   애호박        1개
# 80284       80284  1804520        10          용문시장     23    상추      100g
# 80286       80286  1804522        10          용문시장    312   애호박        1개
# 80301       80301  1804537        63  농협 하나로마트 용산점     23    상추      100g
# 80303       80303  1804539        63  농협 하나로마트 용산점    312   애호박        1개
#
#        가격(원)     년도-월          비고        점검일자  시장유형 구분(시장/마트) 코드  \
# ...

# %%
df_1월 = df_2022[df_2022['년도-월'].isin(['2022-01'])]
df_1월
# Out:
#       Unnamed: 0     일련번호  시장/마트 번호 시장/마트 이름  품목 번호        품목 이름     실판매규격  \
# 0              0  1721871        55     광장시장    305  사과(부사 300g)        1개
# 1              1  1721872        55     광장시장    306   배(신고 600g)        1개
# 2              2  1721873        55     광장시장    307  배추(2.5~3kg)       1포기
# 3              3  1721874        55     광장시장    133       무(세척무)        1개
# 4              4  1721875        55     광장시장     24           양파  1망 1.5kg
# ...          ...      ...       ...      ...    ...          ...       ...
# 8352        8352  1731717       153  이마트 명일점    320      달걀(30개)        특란
# 8353        8353  1731718       153  이마트 명일점    259     조기(냉동국산)       1마리
# 8354        8354  1731719       153  이마트 명일점    264    명태(냉동수입산)       1마리
# 8355        8355  1731720       153  이마트 명일점    256    오징어(냉동국산)       1마리
# 8356        8356  1731721       153  이마트 명일점    266    고등어(생물국산)       1마리
#
#       가격(원)     년도-월        비고        점검일자  시장유형 구분(시장/마트) 코드  \
# ...

# %% [markdown]
# 여기부터 식량 지수 전처리 과정

# %%
df_fi = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Food_price_indices_data_90년부터_23년까지(수정).csv")

df_fi
# Out:
#        Date  Food Price Index   Meat  Dairy  Cereals    Oils  Sugar  \
# 0       NaN               NaN    NaN    NaN      NaN     NaN    NaN
# 1    Jan-90              64.1   73.4   53.5     64.1   44.59   87.9
# 2    Feb-90              64.5   76.0   52.2     62.2   44.50   90.7
# 3    Mar-90              63.8   77.8   41.4     61.3   45.75   95.1
# 4    Apr-90              65.8   80.4   48.4     62.8   44.02   94.3
# ..      ...               ...    ...    ...      ...     ...    ...
# 397  Jan-23             130.2  111.1  134.5    147.5  140.40  116.8
# 398  Feb-23             129.8  113.3  129.4    146.7  135.90  125.2
# 399  Mar-23             127.0  114.7  126.8    138.6  131.80  127.0
# 400  Apr-23             127.7  116.7  122.6    136.1  130.00  149.4
# 401  May-23             124.3  117.9  118.7    129.7  118.70  157.6
#
#      Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 56  Unnamed: 57  \
# 0           NaN         NaN         NaN  ...          NaN          NaN
# ...

# %%
df_18 = df_fi.iloc[337:, :7]
df_18
df_19 = df_18.transpose()
# df_20 = df_19.pivot(index=df_19.index, columns=df_19.columns[0])
df_19 = df_19.iloc[1:]
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df_19
# Out:
#                     337    338    339    340    341    342    343    344  \
# Food Price Index   96.8   97.9   99.0   98.6   98.7   97.0   95.1   96.0
# Meat               95.6   97.0   97.2   95.9   95.3   95.1   94.6   95.8
# Dairy             106.0  108.8  111.3  110.0  111.4  112.3  110.1  108.5
# Cereals            95.2   98.4  101.8  104.0  105.5  100.8   98.7  103.5
# Oils              98.25   95.6  95.36  94.02  92.15  89.33   86.9  84.43
# Sugar              87.2   83.9   80.9   76.8   76.4   77.4   72.5   68.6
#
#                     345    346    347    348    349    350    351    352  \
# Food Price Index   94.2   93.3   92.2   92.2   93.3   94.0   93.2   93.6
# Meat               94.1   92.3   92.9   92.9   92.3   93.1   94.6   97.8
# Dairy             108.3  102.8  100.0   97.8  100.9  103.8  105.6  106.1
# Cereals           100.3  100.9   99.6  101.1  101.8  100.7   97.5   94.6
# Oils              82.33  81.33  76.59  76.84  80.26  81.78  78.41  79.11
# ...

# %%
df_생활물가 =  pd.read_csv("/content/drive/MyDrive/Colab Notebooks/생활물가지수_20230603222211.csv")
df_생활물가1 = df_생활물가.transpose()
# df_생활물가1[''] = df_생활물가1[''].apply(lambda x: f'{x} (생활물가지수)')
# df_생활물가1 = df_생활물가1.drop(0)
# df_생활물가1 = df_생활물가.rename(index=lambda x: '이름')
# df_신선식품지수1['품목별'] = df_신선식품지수1['품목별'].lambda x: f'{x} (신선식품지수)'
# df_생활물가1 = df_생활물가1.iloc[1:]
for i in range(len(df_생활물가1.columns)):
    df_생활물가1.rename(columns={df_생활물가1.columns[i]: i}, inplace=True)
df_생활물가1
# Out:
#                      0         1         2         3         4         5   \
# 시점             2018. 01  2018. 02  2018. 03  2018. 04  2018. 05  2018. 06
# 생활물가지수            103.5    104.42    104.24    104.24    104.22    103.89
# 식품               106.68    108.98    108.46    108.32    108.18    107.01
# 식품 이외            101.89     102.1     102.1    102.18    102.22    102.31
# 전월세               105.4    105.47    105.54    105.66    105.71    105.72
# 전·월세포함 생활물가지수    103.93    104.65    104.53    104.56    104.57    104.31
#
#                      6         7         8         9         10        11  \
# 시점             2018. 07  2018. 08  2018. 09  2018. 10  2018. 11  2018. 12
# 생활물가지수           103.55    104.78    106.09     105.5     104.7     104.2
# 식품               107.48    110.85    113.08     110.7    109.17    108.97
# 식품 이외            101.55    101.72    102.57    102.88    102.46    101.79
# 전월세              105.72    105.82    105.88    105.92    105.95    105.97
# ...

# %%
df_소비자물가지수 =  pd.read_csv("/content/drive/MyDrive/Colab Notebooks/소비자물가지수_2020100__20230603125911.csv", encoding='cp949')
df_소비자물가지수 = df_소비자물가지수.iloc[:, :-5]
df_소비자물가지수['시도별'] = df_소비자물가지수['시도별'].replace({'전국': '소비자물가지수(단일)'})
df_소비자물가지수 = df_소비자물가지수.rename(columns={"시도별": ""})
for i in range(len(df_소비자물가지수.columns)):
     df_소비자물가지수.rename(columns={df_소비자물가지수.columns[i]: i}, inplace=True)
df_소비자물가지수
# Out:
#             0       1       2       3       4       5       6      7       8   \
# 0  소비자물가지수(단일)  98.106  98.855  98.751  98.931  98.979  98.779  98.59  99.462
#
#         9   ...      51      52      53      54      55      56      57  \
# 0  100.221  ...  106.06  106.85  107.56  108.22  108.74  108.62  108.93
#
#        58     59      60
# 0  109.21  109.1  109.28
#
# [1 rows x 61 columns]

# %%
df_신선식품지수 =  pd.read_csv("/content/drive/MyDrive/Colab Notebooks/신선식품지수_2020100__20230603130414.csv", encoding='cp949')
df_신선식품지수1 = df_신선식품지수.iloc[:, 1:-5]
df_신선식품지수1['품목별'] = df_신선식품지수1['품목별'].apply(lambda x: f'{x} (신선식품지수)')
df_신선식품지수1 = df_신선식품지수1.rename(columns={"품목별": ""})
for i in range(len(df_신선식품지수1.columns)):
    df_신선식품지수1.rename(columns={df_신선식품지수1.columns[i]: i}, inplace=True)
df_신선식품지수1
# Out:
#                 0       1        2       3        4       5       6       7   \
# 0     총지수 (신선식품지수)  98.106   98.855  98.751   98.931  98.979  98.779  98.590
# 1    신선식품 (신선식품지수)  92.961  101.268  95.890   96.269  92.838  87.690  86.915
# 2    신선어개 (신선식품지수)  92.806   93.193  93.773   94.454  95.018  95.018  94.454
# 3    신선채소 (신선식품지수)  88.511  104.029  94.878   92.009  87.749  79.880  83.045
# 4    신선과실 (신선식품지수)  98.010  103.661  98.444  102.196  97.005  91.380  86.120
# 5  신선식품제외 (신선식품지수)  98.332   98.752  98.876   99.057  99.258  99.267  99.124
#
#         8        9   ...      51      52      53      54      55      56  \
# 0   99.462  100.221  ...  106.06  106.85  107.56  108.22  108.74  108.62
# 1  102.745  112.322  ...  109.35  109.62  107.46  106.36  113.70  119.80
# 2   92.848   92.007  ...  102.99  104.36  104.85  104.54  103.39  102.73
# 3  107.551  123.374  ...  104.28  102.49   98.50   96.84  113.57  126.88
# ...

# %%
df_수입물가지수 =  pd.read_csv("/content/drive/MyDrive/Colab Notebooks/품목별 수입물가지수.csv")
df_수입물가지수
df_수입물가지수 = df_수입물가지수[df_수입물가지수['계정코드별'].isin(["총지수", "과일", "쇠고기", "돼지고기", "닭고기", "신선수산물","냉동수산물", "냉동채소"])]
df_수입물가지수 = df_수입물가지수 .drop(columns=[df_수입물가지수 .columns[1]])
df_수입물가지수 = df_수입물가지수.drop(df_수입물가지수.columns[1:13], axis=1)
df_수입물가지수
df_수입물가지수['계정코드별'] = df_수입물가지수['계정코드별'].apply(lambda x: f'{x} (수입물가지수)')
df_수입물가지수 = df_수입물가지수.rename(columns={"계정코드별": " "})
df_수입물가지수.columns = df_수입물가지수.columns.str.replace("-", ".")
for i in range(len(df_수입물가지수.columns)):
    df_수입물가지수.rename(columns={df_수입물가지수.columns[i]: i}, inplace=True)
df_수입물가지수
# Out:
#                 0       1       2       3       4       5       6       7   \
# 0     총지수 (수입물가지수)  103.37  103.84  104.39  105.53  108.64  110.01  111.50
# 5      과일 (수입물가지수)  103.80  106.18  102.79  112.50  108.63  107.66  103.23
# 6    냉동채소 (수입물가지수)   91.05   92.15   87.21   83.70   84.95   86.25   88.65
# 7     쇠고기 (수입물가지수)   83.63   86.65   83.80   83.27   86.05   87.42   90.80
# 8    돼지고기 (수입물가지수)  116.31  118.08  116.90  116.59  117.31  117.17  113.56
# 9     닭고기 (수입물가지수)   99.54  104.89  106.42  106.50  109.38  121.97  133.25
# 10  신선수산물 (수입물가지수)  100.79  102.40  105.41  106.63  100.47   93.73   83.42
# 11  냉동수산물 (수입물가지수)   94.82   97.18   96.49   96.83   99.97  104.88  106.38
#
#         8       9   ...      51      52      53      54      55      56  \
# 0   111.18  113.03  ...  149.23  148.38  154.00  154.87  150.78  149.46
# 5   105.09  103.88  ...  116.64  120.32  131.50  136.68  139.06  137.42
# 6    87.94   89.38  ...  164.56  162.14  165.51  166.66  175.33  177.97
# ...

# %%
df_품목별소비자물가 =  pd.read_csv("/content/drive/MyDrive/Colab Notebooks/품목별소비자물가지수_201801~202306.csv", encoding='cp949')
df_품목별소비자물가 = df_품목별소비자물가.drop([df_품목별소비자물가.columns[0], df_품목별소비자물가.columns[2], df_품목별소비자물가.columns[3]], axis=1)
df_품목별소비자물가["품목별"].unique()
df_품목별소비자물가_수정 = df_품목별소비자물가[df_품목별소비자물가['품목별'].isin(["총지수", "고등어", "갈치", "물오징어", "조기", "냉동참조기","명태", "동태", "삼겹살","애호박", "닭고기", "쇠고기", "돼지고기", "달걀", "호박", "오이", "양파", "상추", "배추", "배", "사과"])]
df_품목별소비자물가_수정
df_품목별소비자물가_수정['품목별'] = df_품목별소비자물가_수정['품목별'].apply(lambda x: f'{x} (품목별소비자물가)')
df_품목별소비자물가_수정 = df_품목별소비자물가_수정.iloc[:, :-6]
df_품목별소비자물가_수정 = df_품목별소비자물가_수정.rename(columns={"품목별": " "})
df_품목별소비자물가_수정.columns = df_품목별소비자물가_수정.columns.str.replace(" 월", "")
for i in range(len(df_품목별소비자물가_수정.columns)):
    df_품목별소비자물가_수정.rename(columns={df_품목별소비자물가_수정.columns[i]: i}, inplace=True)

# 결과 출력
df_품목별소비자물가_수정
# Out:
# <ipython-input-191-19b61c3c1291>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_품목별소비자물가_수정['품목별'] = df_품목별소비자물가_수정['품목별'].apply(lambda x: f'{x} (품목별소비자물가)')
#                  0        1        2        3        4        5        6   \
# 0    총지수 (품목별소비자물가)   98.106   98.855   98.751   98.931   98.979   98.779
# 11    배추 (품목별소비자물가)   60.266   83.293   83.786   83.593   67.793   54.508
# 12    상추 (품목별소비자물가)   89.102   92.305   74.956   76.172   73.384   73.609
# 26    오이 (품목별소비자물가)  113.848  130.452  102.050   88.483   78.881   75.259
# 28    호박 (품목별소비자물가)  106.958  138.009  116.630   85.967   77.202   70.743
# 32    양파 (품목별소비자물가)   99.880   99.958   95.790   83.983   81.225   78.327
# ...

# %%
df_생산자물가지수 =  pd.read_csv("/content/drive/MyDrive/Colab Notebooks/생산자물가지수(csv).csv", encoding='cp949')
df_생산자물가지수["계정코드별"].unique()
df_생산자물가지수_수정 = df_생산자물가지수[df_생산자물가지수['계정코드별'].isin(["총지수", "고등어", "갈치", "물오징어", "조기", "기타어류", "닭고기", "쇠고기", "돼지고기", "달걀", "호박", "오이", "양파", "상추", "배추", "배", "사과"])]
df_생산자물가지수_수정
df_생산자물가지수_수정1 = df_생산자물가지수_수정.drop(df_생산자물가지수_수정.columns[1:14], axis=1)
df_생산자물가지수_수정1['계정코드별'] = df_생산자물가지수_수정1['계정코드별'].apply(lambda x: f'{x} (생산자물가지수)')
df_생산자물가지수_수정1 = df_생산자물가지수_수정1.rename(columns={"계정코드별": " "})
df_생산자물가지수_수정1.columns = df_생산자물가지수_수정1.columns.str.replace("-", ".")
for i in range(len(df_생산자물가지수_수정1.columns)):
    df_생산자물가지수_수정1.rename(columns={df_생산자물가지수_수정1.columns[i]: i}, inplace=True)
df_생산자물가지수_수정1
# Out:
#                 0       1       2       3       4       5       6       7   \
# 0    총지수 (생산자물가지수)  102.52  102.95  102.91  103.04  103.34  103.37  103.85
# 10    배추 (생산자물가지수)  127.75  166.11  165.05  151.57  119.08   97.27  185.01
# 13    상추 (생산자물가지수)  118.13   91.33   62.05   68.34   71.56   53.69  115.41
# 17    오이 (생산자물가지수)  129.49  115.58  106.14   72.55   72.03   56.20   85.37
# 18    호박 (생산자물가지수)  140.56  154.64  148.04   87.99   92.34   55.41   51.87
# 27    양파 (생산자물가지수)  109.45  104.46   76.34   67.63   68.79   59.22   57.07
# 32    사과 (생산자물가지수)   59.04   65.29   65.01   64.03   61.97   62.55   61.41
# 33     배 (생산자물가지수)   91.32   99.17   95.08   93.92   91.26   92.58   89.71
# 41   쇠고기 (생산자물가지수)  105.02  108.76  107.27  108.11  107.69  108.23  104.70
# 42  돼지고기 (생산자물가지수)   82.61   84.52   84.31   91.87   98.57  109.42  110.55
# 43   닭고기 (생산자물가지수)   76.96   90.42   99.28   96.73   95.71   84.68   96.80
# ...

# %%
# df_19
# df_생활물가1
# df_소비자물가지수
# df_신선식품지수1
# df_수입물가지수
# df_품목별소비자물가_수정
# df_생산자물가지수_수정1

# 합치려는 데이터프레임들을 리스트로 저장
dataframes = [df_소비자물가지수, df_신선식품지수1, df_수입물가지수, df_품목별소비자물가_수정, df_생산자물가지수_수정1]

# 데이터프레임들을 열 방향으로 합치기
merged_df = pd.concat(dataframes, axis=0)

# 결과 출력
merged_df
# Out:
#                  0        1        2        3        4        5        6   \
# 0       소비자물가지수(단일)   98.106   98.855   98.751   98.931   98.979   98.779
# 0      총지수 (신선식품지수)   98.106   98.855   98.751   98.931   98.979   98.779
# 1     신선식품 (신선식품지수)   92.961  101.268   95.890   96.269   92.838   87.690
# 2     신선어개 (신선식품지수)   92.806   93.193   93.773   94.454   95.018   95.018
# 3     신선채소 (신선식품지수)   88.511  104.029   94.878   92.009   87.749   79.880
# 4     신선과실 (신선식품지수)   98.010  103.661   98.444  102.196   97.005   91.380
# 5   신선식품제외 (신선식품지수)   98.332   98.752   98.876   99.057   99.258   99.267
# 0      총지수 (수입물가지수)  103.370  103.840  104.390  105.530  108.640  110.010
# 5       과일 (수입물가지수)  103.800  106.180  102.790  112.500  108.630  107.660
# 6     냉동채소 (수입물가지수)   91.050   92.150   87.210   83.700   84.950   86.250
# 7      쇠고기 (수입물가지수)   83.630   86.650   83.800   83.270   86.050   87.420
# 8     돼지고기 (수입물가지수)  116.310  118.080  116.900  116.590  117.310  117.170
# ...

# %%
merged_df.to_csv('merged_data.csv', index=False)

# 다운로드 링크 생성
from google.colab import files
files.download('merged_data.csv')
